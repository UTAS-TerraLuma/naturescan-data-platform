# %% [markdown]
# # 01. Create COG
#
# Implementation moved to [ns_cogger](./ns_cogger.py). See that file for details.

# %%
from ns_configs import RGB_ASSET_CONFIG, MS_ASSET_CONFIG
from ns_cogger import create_cog
from pathlib import Path

force = False
limit = None
input_dir = Path("/home/jamesg/test_data/naturescan")

# %% [markdown]
# ## RGB COGs

# %%
# Get All RGB Tif Files
rgb_tif_files = list(input_dir.rglob("*rgb.tif", case_sensitive=False))

# Limit total (does nothing if limit is None)
rgb_tif_files = rgb_tif_files[0:limit]
print(f"Found {len(rgb_tif_files)} RGB GeoTiff files.")

# Create COG for each
for i, input in enumerate(rgb_tif_files):
    print(f"Processing {input.name} ({i + 1} / {len(rgb_tif_files)}) ...")
    try:
        create_cog(input, input.with_suffix('.cog.tif'), RGB_ASSET_CONFIG, force=force)
    except Exception as e:
        print(f"Error processing: {input.name}")
        print(e)
# Out:
# Found 20 RGB GeoTiff files.
# Processing 20250204_TCNSTCH005_m3m_60mAGL_ortho_RGB.tif (1 / 20) ...
# Successfully converted 20250204_TCNSTCH005_m3m_60mAGL_ortho_RGB.tif to 20250204_TCNSTCH005_m3m_60mAGL_ortho_RGB.cog.tif.
# Processing 20251118_TCNSTSE008_m3m_50mAGL_ortho_rgb.tif (2 / 20) ...
# Successfully converted 20251118_TCNSTSE008_m3m_50mAGL_ortho_rgb.tif to 20251118_TCNSTSE008_m3m_50mAGL_ortho_rgb.cog.tif.
# Processing 20251118_TCNSTSE009_m3m_50mAGL_ortho_rgb.tif (3 / 20) ...
# Successfully converted 20251118_TCNSTSE009_m3m_50mAGL_ortho_rgb.tif to 20251118_TCNSTSE009_m3m_50mAGL_ortho_rgb.cog.tif.
# Processing 20251120_TCNSTSE013_m3m_50mAGL_ortho_rgb.tif (4 / 20) ...
# Successfully converted 20251120_TCNSTSE013_m3m_50mAGL_ortho_rgb.tif to 20251120_TCNSTSE013_m3m_50mAGL_ortho_rgb.cog.tif.
# Processing 20241002_SAAGAW0007_m3m_50mAGL_ortho_RGB.tif (5 / 20) ...
# Skipping 20241002_SAAGAW0007_m3m_50mAGL_ortho_RGB.tif as 20241002_SAAGAW0007_m3m_50mAGL_ortho_RGB.cog.tif already exists.
# Processing 20241002_SAASTP0033_m3m_100mAGL_ortho_RGB.tif (6 / 20) ...
# Skipping 20241002_SAASTP0033_m3m_100mAGL_ortho_RGB.tif as 20241002_SAASTP0033_m3m_100mAGL_ortho_RGB.cog.tif already exists.
# Processing 20241001_SAAGAW0008_m3m_100mAGL_ortho_rgb.tif (7 / 20) ...
# Skipping 20241001_SAAGAW0008_m3m_100mAGL_ortho_rgb.tif as 20241001_SAAGAW0008_m3m_100mAGL_ortho_rgb.cog.tif already exists.
# Processing 20241001_SAAGAW0009_m3m_50mAGL_ortho_RGB.tif (8 / 20) ...
# Skipping 20241001_SAAGAW0009_m3m_50mAGL_ortho_RGB.tif as 20241001_SAAGAW0009_m3m_50mAGL_ortho_RGB.cog.tif already exists.
# Processing 20241001_SAAGAW0004_m3m_50mAGL_ortho_RGB.tif (9 / 20) ...
# Skipping 20241001_SAAGAW0004_m3m_50mAGL_ortho_RGB.tif as 20241001_SAAGAW0004_m3m_50mAGL_ortho_RGB.cog.tif already exists.
# Processing 20240925_NTAFIN0014_m3m_100mAGL_ortho_RGB.tif (10 / 20) ...
# Successfully converted 20240925_NTAFIN0014_m3m_100mAGL_ortho_RGB.tif to 20240925_NTAFIN0014_m3m_100mAGL_ortho_RGB.cog.tif.
# Processing 20240925_NTAFIN0013_m3m_50mAGL_ortho_RGB.tif (11 / 20) ...
# Successfully converted 20240925_NTAFIN0013_m3m_50mAGL_ortho_RGB.tif to 20240925_NTAFIN0013_m3m_50mAGL_ortho_RGB.cog.tif.
# Processing 20241210_SANSSTP014_m3m_50mAGL_ortho_rgb.tif (12 / 20) ...
# Skipping 20241210_SANSSTP014_m3m_50mAGL_ortho_rgb.tif as 20241210_SANSSTP014_m3m_50mAGL_ortho_rgb.cog.tif already exists.
# Processing 20241210_SANSSTP020_m3m_50mAGL_ortho_rgb.tif (13 / 20) ...
# Skipping 20241210_SANSSTP020_m3m_50mAGL_ortho_rgb.tif as 20241210_SANSSTP020_m3m_50mAGL_ortho_rgb.cog.tif already exists.
# Processing 20240812_SANSSTP009_m3m_70mAGL_ortho_rgb.tif (14 / 20) ...
# Skipping 20240812_SANSSTP009_m3m_70mAGL_ortho_rgb.tif as 20240812_SANSSTP009_m3m_70mAGL_ortho_rgb.cog.tif already exists.
# Processing 20241209_SANSSTP010_m3m_50mAGL_ortho_rgb.tif (15 / 20) ...
# Skipping 20241209_SANSSTP010_m3m_50mAGL_ortho_rgb.tif as 20241209_SANSSTP010_m3m_50mAGL_ortho_rgb.cog.tif already exists.
# Processing 20241208_SANSSTP005_m3m_60mAGL_ortho_rgb.tif (16 / 20) ...
# Skipping 20241208_SANSSTP005_m3m_60mAGL_ortho_rgb.tif as 20241208_SANSSTP005_m3m_60mAGL_ortho_rgb.cog.tif already exists.
# Processing 20241208_SANSSTP006_m3m_110mAGL_ortho_rgb.tif (17 / 20) ...
# Skipping 20241208_SANSSTP006_m3m_110mAGL_ortho_rgb.tif as 20241208_SANSSTP006_m3m_110mAGL_ortho_rgb.cog.tif already exists.
# Processing 20241210_SANSSTP016_m3m_50mAGL_ortho_RGB.tif (18 / 20) ...
# Skipping 20241210_SANSSTP016_m3m_50mAGL_ortho_RGB.tif as 20241210_SANSSTP016_m3m_50mAGL_ortho_RGB.cog.tif already exists.
# Processing 20241207_SANSSTP002_m3m_50mAGL_ortho_rgb.tif (19 / 20) ...
# Skipping 20241207_SANSSTP002_m3m_50mAGL_ortho_rgb.tif as 20241207_SANSSTP002_m3m_50mAGL_ortho_rgb.cog.tif already exists.
# Processing 20241208_SAASTP0041_m3m_50mAGL_ortho_RGB.tif (20 / 20) ...
# Skipping 20241208_SAASTP0041_m3m_50mAGL_ortho_RGB.tif as 20241208_SAASTP0041_m3m_50mAGL_ortho_RGB.cog.tif already exists.

# %% [markdown]
# ## MS COGs

# %%
# Get All RGB Tif Files
ms_tif_files = list(input_dir.rglob("*ms.tif", case_sensitive=False))

# Limit total (does nothing if limit is None)
ms_tif_files = ms_tif_files[0:limit]
print(f"Found {len(ms_tif_files)} MS GeoTiff files.")

# Create COG for each
for i, input in enumerate(ms_tif_files):
    print(f"Processing {input.name} ({i + 1} / {len(ms_tif_files)}) ...")
    try:
        create_cog(input, input.with_suffix('.cog.tif'), MS_ASSET_CONFIG, force=force)
    except Exception as e:
        print(f"Error processing: {input.name}")
        print(e)
# Out:
# Found 20 MS GeoTiff files.
# Processing 20250204_TCNSTCH005_m3m_60mAGL_ortho_MS.tif (1 / 20) ...
# Successfully converted 20250204_TCNSTCH005_m3m_60mAGL_ortho_MS.tif to 20250204_TCNSTCH005_m3m_60mAGL_ortho_MS.cog.tif.
# Processing 20260116_TCNSTSE008_m3m_50mAGL_ortho_ms.tif (2 / 20) ...
# Successfully converted 20260116_TCNSTSE008_m3m_50mAGL_ortho_ms.tif to 20260116_TCNSTSE008_m3m_50mAGL_ortho_ms.cog.tif.
# Processing 20251118_TCNSTSE009_m3m_50mAGL_ortho_ms.tif (3 / 20) ...
# Successfully converted 20251118_TCNSTSE009_m3m_50mAGL_ortho_ms.tif to 20251118_TCNSTSE009_m3m_50mAGL_ortho_ms.cog.tif.
# Processing 20251120_TCNSTSE013_m3m_50mAGL_ortho_ms.tif (4 / 20) ...
# Successfully converted 20251120_TCNSTSE013_m3m_50mAGL_ortho_ms.tif to 20251120_TCNSTSE013_m3m_50mAGL_ortho_ms.cog.tif.
# Processing 20241002_SAAGAW0007_m3m_50mAGL_ortho_MS.tif (5 / 20) ...
# Skipping 20241002_SAAGAW0007_m3m_50mAGL_ortho_MS.tif as 20241002_SAAGAW0007_m3m_50mAGL_ortho_MS.cog.tif already exists.
# Processing 20241002_SAASTP0033_m3m_100mAGL_ortho_MS.tif (6 / 20) ...
# Skipping 20241002_SAASTP0033_m3m_100mAGL_ortho_MS.tif as 20241002_SAASTP0033_m3m_100mAGL_ortho_MS.cog.tif already exists.
# Processing 20241001_SAAGAW0008_m3m_100mAGL_ortho_ms.tif (7 / 20) ...
# Skipping 20241001_SAAGAW0008_m3m_100mAGL_ortho_ms.tif as 20241001_SAAGAW0008_m3m_100mAGL_ortho_ms.cog.tif already exists.
# Processing 20241001_SAAGAW0009_m3m_50mAGL_ortho_MS.tif (8 / 20) ...
# Skipping 20241001_SAAGAW0009_m3m_50mAGL_ortho_MS.tif as 20241001_SAAGAW0009_m3m_50mAGL_ortho_MS.cog.tif already exists.
# Processing 20241001_SAAGAW0004_m3m_50mAGL_ortho_MS.tif (9 / 20) ...
# Skipping 20241001_SAAGAW0004_m3m_50mAGL_ortho_MS.tif as 20241001_SAAGAW0004_m3m_50mAGL_ortho_MS.cog.tif already exists.
# Processing 20240925_NTAFIN0014_m3m_100mAGL_ortho_MS.tif (10 / 20) ...
# Successfully converted 20240925_NTAFIN0014_m3m_100mAGL_ortho_MS.tif to 20240925_NTAFIN0014_m3m_100mAGL_ortho_MS.cog.tif.
# Processing 20240925_NTAFIN0013_m3m_50mAGL_ortho_MS.tif (11 / 20) ...
# Successfully converted 20240925_NTAFIN0013_m3m_50mAGL_ortho_MS.tif to 20240925_NTAFIN0013_m3m_50mAGL_ortho_MS.cog.tif.
# Processing 20241210_SANSSTP014_m3m_50mAGL_ortho_ms.tif (12 / 20) ...
# Skipping 20241210_SANSSTP014_m3m_50mAGL_ortho_ms.tif as 20241210_SANSSTP014_m3m_50mAGL_ortho_ms.cog.tif already exists.
# Processing 20241210_SANSSTP020_m3m_50mAGL_ortho_ms.tif (13 / 20) ...
# Skipping 20241210_SANSSTP020_m3m_50mAGL_ortho_ms.tif as 20241210_SANSSTP020_m3m_50mAGL_ortho_ms.cog.tif already exists.
# Processing 20240812_SANSSTP009_m3m_70mAGL_ortho_ms.tif (14 / 20) ...
# Skipping 20240812_SANSSTP009_m3m_70mAGL_ortho_ms.tif as 20240812_SANSSTP009_m3m_70mAGL_ortho_ms.cog.tif already exists.
# Processing 20241209_SANSSTP010_m3m_50mAGL_ortho_ms.tif (15 / 20) ...
# Skipping 20241209_SANSSTP010_m3m_50mAGL_ortho_ms.tif as 20241209_SANSSTP010_m3m_50mAGL_ortho_ms.cog.tif already exists.
# Processing 20241208_SANSSTP005_m3m_60mAGL_ortho_ms.tif (16 / 20) ...
# Skipping 20241208_SANSSTP005_m3m_60mAGL_ortho_ms.tif as 20241208_SANSSTP005_m3m_60mAGL_ortho_ms.cog.tif already exists.
# Processing 20241208_SANSSTP006_m3m_110mAGL_ortho_ms.tif (17 / 20) ...
# Skipping 20241208_SANSSTP006_m3m_110mAGL_ortho_ms.tif as 20241208_SANSSTP006_m3m_110mAGL_ortho_ms.cog.tif already exists.
# Processing 20241210_SANSSTP016_m3m_50mAGL_ortho_MS.tif (18 / 20) ...
# Skipping 20241210_SANSSTP016_m3m_50mAGL_ortho_MS.tif as 20241210_SANSSTP016_m3m_50mAGL_ortho_MS.cog.tif already exists.
# Processing 20241207_SANSSTP002_m3m_50mAGL_ortho_ms.tif (19 / 20) ...
# Skipping 20241207_SANSSTP002_m3m_50mAGL_ortho_ms.tif as 20241207_SANSSTP002_m3m_50mAGL_ortho_ms.cog.tif already exists.
# Processing 20241208_SAASTP0041_m3m_50mAGL_ortho_MS.tif (20 / 20) ...
# Skipping 20241208_SAASTP0041_m3m_50mAGL_ortho_MS.tif as 20241208_SAASTP0041_m3m_50mAGL_ortho_MS.cog.tif already exists.
