# %% [markdown]
# # 02 Create Thumbnails

# %%
from ns_configs import RGB_ASSET_CONFIG, MS_ASSET_CONFIG
from ns_cogger import create_thumbnail
from pathlib import Path

force = True
limit = None
input_dir = Path("/home/jamesg/test_data/naturescan")

# %% [markdown]
# ## RGB Thumbnails

# %%
# Get All RGB Tif Files
rgb_cogs = list(input_dir.rglob("*rgb.cog.tif", case_sensitive=False))

# Limit total (does nothing if limit is None)
rgb_cogs = rgb_cogs[0:limit]
print(f"Found {len(rgb_cogs)} RGB COGs.")

# Create a thumbnail for each COG
for i, input in enumerate(rgb_cogs):
    print(f"Processing {input.name} ({i + 1} / {len(rgb_cogs)}) ...")
    try:
        output = input.with_name(input.name.replace('.cog.tif', '.thumbnail.png'))
        create_thumbnail(input, output, force=force)
    except Exception as e:
        print(f"Error processing: {input.name}")
        print(e)
# Out:
# Found 20 RGB COGs.
# Processing 20250204_TCNSTCH005_m3m_60mAGL_ortho_RGB.cog.tif (1 / 20) ...
# Successfully created thumbnail for 20250204_TCNSTCH005_m3m_60mAGL_ortho_RGB.cog.tif at /home/jamesg/test_data/naturescan/TheValeOfBelvoir/TCNSTCH005/20250204_TCNSTCH005_m3m_60mAGL_ortho_RGB.thumbnail.png
# Processing 20251118_TCNSTSE008_m3m_50mAGL_ortho_rgb.cog.tif (2 / 20) ...
# Successfully created thumbnail for 20251118_TCNSTSE008_m3m_50mAGL_ortho_rgb.cog.tif at /home/jamesg/test_data/naturescan/KelvedonHills/TCNSTSE008/m3m/level1_proc/20251118_TCNSTSE008_m3m_50mAGL_ortho_rgb.thumbnail.png
# Processing 20251118_TCNSTSE009_m3m_50mAGL_ortho_rgb.cog.tif (3 / 20) ...
# Successfully created thumbnail for 20251118_TCNSTSE009_m3m_50mAGL_ortho_rgb.cog.tif at /home/jamesg/test_data/naturescan/KelvedonHills/TCNSTSE009/m3m/level1_proc/20251118_TCNSTSE009_m3m_50mAGL_ortho_rgb.thumbnail.png
# Processing 20251120_TCNSTSE013_m3m_50mAGL_ortho_rgb.cog.tif (4 / 20) ...
# Successfully created thumbnail for 20251120_TCNSTSE013_m3m_50mAGL_ortho_rgb.cog.tif at /home/jamesg/test_data/naturescan/KelvedonHills/TCNSTSE013/m3m/level1_proc/20251120_TCNSTSE013_m3m_50mAGL_ortho_rgb.thumbnail.png
# Processing 20241002_SAAGAW0007_m3m_50mAGL_ortho_RGB.cog.tif (5 / 20) ...
# Successfully created thumbnail for 20241002_SAAGAW0007_m3m_50mAGL_ortho_RGB.cog.tif at /home/jamesg/test_data/naturescan/BonBon/SAAGAW0007/20241002_SAAGAW0007_m3m_50mAGL_ortho_RGB.thumbnail.png
# Processing 20241002_SAASTP0033_m3m_100mAGL_ortho_RGB.cog.tif (6 / 20) ...
# Successfully created thumbnail for 20241002_SAASTP0033_m3m_100mAGL_ortho_RGB.cog.tif at /home/jamesg/test_data/naturescan/BonBon/SAASTP0033/20241002_SAASTP0033_m3m_100mAGL_ortho_RGB.thumbnail.png
# Processing 20241001_SAAGAW0008_m3m_100mAGL_ortho_rgb.cog.tif (7 / 20) ...
# Successfully created thumbnail for 20241001_SAAGAW0008_m3m_100mAGL_ortho_rgb.cog.tif at /home/jamesg/test_data/naturescan/BonBon/SAAGAW0008/20241001_SAAGAW0008_m3m_100mAGL_ortho_rgb.thumbnail.png
# Processing 20241001_SAAGAW0009_m3m_50mAGL_ortho_RGB.cog.tif (8 / 20) ...
# Successfully created thumbnail for 20241001_SAAGAW0009_m3m_50mAGL_ortho_RGB.cog.tif at /home/jamesg/test_data/naturescan/BonBon/SAAGAW0009/20241001_SAAGAW0009_m3m_50mAGL_ortho_RGB.thumbnail.png
# Processing 20241001_SAAGAW0004_m3m_50mAGL_ortho_RGB.cog.tif (9 / 20) ...
# Successfully created thumbnail for 20241001_SAAGAW0004_m3m_50mAGL_ortho_RGB.cog.tif at /home/jamesg/test_data/naturescan/BonBon/SAAGAW0004/20241001/20241001_SAAGAW0004_m3m_50mAGL_ortho_RGB.thumbnail.png
# Processing 20240925_NTAFIN0014_m3m_100mAGL_ortho_RGB.cog.tif (10 / 20) ...
# Successfully created thumbnail for 20240925_NTAFIN0014_m3m_100mAGL_ortho_RGB.cog.tif at /home/jamesg/test_data/naturescan/NTAFIN/NTAFIN0014/20240925_NTAFIN0014_m3m_100mAGL_ortho_RGB.thumbnail.png
# Processing 20240925_NTAFIN0013_m3m_50mAGL_ortho_RGB.cog.tif (11 / 20) ...
# Successfully created thumbnail for 20240925_NTAFIN0013_m3m_50mAGL_ortho_RGB.cog.tif at /home/jamesg/test_data/naturescan/NTAFIN/NTAFIN0013/20240925_NTAFIN0013_m3m_50mAGL_ortho_RGB.thumbnail.png
# Processing 20241210_SANSSTP014_m3m_50mAGL_ortho_rgb.cog.tif (12 / 20) ...
# Successfully created thumbnail for 20241210_SANSSTP014_m3m_50mAGL_ortho_rgb.cog.tif at /home/jamesg/test_data/naturescan/EvelynDowns/SANSSTP014/20241210_SANSSTP014_m3m_50mAGL_ortho_rgb.thumbnail.png
# Processing 20241210_SANSSTP020_m3m_50mAGL_ortho_rgb.cog.tif (13 / 20) ...
# Successfully created thumbnail for 20241210_SANSSTP020_m3m_50mAGL_ortho_rgb.cog.tif at /home/jamesg/test_data/naturescan/EvelynDowns/SANSSTP020/20241210_SANSSTP020_m3m_50mAGL_ortho_rgb.thumbnail.png
# Processing 20240812_SANSSTP009_m3m_70mAGL_ortho_rgb.cog.tif (14 / 20) ...
# Successfully created thumbnail for 20240812_SANSSTP009_m3m_70mAGL_ortho_rgb.cog.tif at /home/jamesg/test_data/naturescan/EvelynDowns/SANSSTP009/20240812_SANSSTP009_m3m_70mAGL_ortho_rgb.thumbnail.png
# Processing 20241209_SANSSTP010_m3m_50mAGL_ortho_rgb.cog.tif (15 / 20) ...
# Successfully created thumbnail for 20241209_SANSSTP010_m3m_50mAGL_ortho_rgb.cog.tif at /home/jamesg/test_data/naturescan/EvelynDowns/SANSSTP010/20241209_SANSSTP010_m3m_50mAGL_ortho_rgb.thumbnail.png
# Processing 20241208_SANSSTP005_m3m_60mAGL_ortho_rgb.cog.tif (16 / 20) ...
# Successfully created thumbnail for 20241208_SANSSTP005_m3m_60mAGL_ortho_rgb.cog.tif at /home/jamesg/test_data/naturescan/EvelynDowns/SANSSTP005/20241208_SANSSTP005_m3m_60mAGL_ortho_rgb.thumbnail.png
# Processing 20241208_SANSSTP006_m3m_110mAGL_ortho_rgb.cog.tif (17 / 20) ...
# Successfully created thumbnail for 20241208_SANSSTP006_m3m_110mAGL_ortho_rgb.cog.tif at /home/jamesg/test_data/naturescan/EvelynDowns/SANSSTP006/20241208_SANSSTP006_m3m_110mAGL_ortho_rgb.thumbnail.png
# Processing 20241210_SANSSTP016_m3m_50mAGL_ortho_RGB.cog.tif (18 / 20) ...
# Successfully created thumbnail for 20241210_SANSSTP016_m3m_50mAGL_ortho_RGB.cog.tif at /home/jamesg/test_data/naturescan/EvelynDowns/SANSSTP016/20241210_SANSSTP016_m3m_50mAGL_ortho_RGB.thumbnail.png
# Processing 20241207_SANSSTP002_m3m_50mAGL_ortho_rgb.cog.tif (19 / 20) ...
# Successfully created thumbnail for 20241207_SANSSTP002_m3m_50mAGL_ortho_rgb.cog.tif at /home/jamesg/test_data/naturescan/EvelynDowns/SANSSTP002/20241207_SANSSTP002_m3m_50mAGL_ortho_rgb.thumbnail.png
# Processing 20241208_SAASTP0041_m3m_50mAGL_ortho_RGB.cog.tif (20 / 20) ...
# Successfully created thumbnail for 20241208_SAASTP0041_m3m_50mAGL_ortho_RGB.cog.tif at /home/jamesg/test_data/naturescan/EvelynDowns/SANSSTP0041/20241208_SAASTP0041_m3m_50mAGL_ortho_RGB.thumbnail.png

# %% [markdown]
# ## MS Thumbnails

# %%
# Get all MS COGS
ms_cogs = list(input_dir.rglob("*ms.cog.tif", case_sensitive=False))

# Limit total (does nothing if limit is None)
ms_cogs = ms_cogs[0:limit]
print(f"Found {len(ms_cogs)} RGB COGs.")

# Create a thumbnail for each COG
for i, input in enumerate(ms_cogs):
    print(f"Processing {input.name} ({i + 1} / {len(ms_cogs)}) ...")
    try:
        output = input.with_name(input.name.replace('.cog.tif', '.thumbnail.png'))
        create_thumbnail(input, output, force=force)
    except Exception as e:
        print(f"Error processing: {input.name}")
        print(e)
# Out:
# Found 20 RGB COGs.
# Processing 20250204_TCNSTCH005_m3m_60mAGL_ortho_MS.cog.tif (1 / 20) ...
# Successfully created thumbnail for 20250204_TCNSTCH005_m3m_60mAGL_ortho_MS.cog.tif at /home/jamesg/test_data/naturescan/TheValeOfBelvoir/TCNSTCH005/20250204_TCNSTCH005_m3m_60mAGL_ortho_MS.thumbnail.png
# Processing 20260116_TCNSTSE008_m3m_50mAGL_ortho_ms.cog.tif (2 / 20) ...
# Successfully created thumbnail for 20260116_TCNSTSE008_m3m_50mAGL_ortho_ms.cog.tif at /home/jamesg/test_data/naturescan/KelvedonHills/TCNSTSE008/m3m/level1_proc/20260116_TCNSTSE008_m3m_50mAGL_ortho_ms.thumbnail.png
# Processing 20251118_TCNSTSE009_m3m_50mAGL_ortho_ms.cog.tif (3 / 20) ...
# Successfully created thumbnail for 20251118_TCNSTSE009_m3m_50mAGL_ortho_ms.cog.tif at /home/jamesg/test_data/naturescan/KelvedonHills/TCNSTSE009/m3m/level1_proc/20251118_TCNSTSE009_m3m_50mAGL_ortho_ms.thumbnail.png
# Processing 20251120_TCNSTSE013_m3m_50mAGL_ortho_ms.cog.tif (4 / 20) ...
# Successfully created thumbnail for 20251120_TCNSTSE013_m3m_50mAGL_ortho_ms.cog.tif at /home/jamesg/test_data/naturescan/KelvedonHills/TCNSTSE013/m3m/level1_proc/20251120_TCNSTSE013_m3m_50mAGL_ortho_ms.thumbnail.png
# Processing 20241002_SAAGAW0007_m3m_50mAGL_ortho_MS.cog.tif (5 / 20) ...
# Successfully created thumbnail for 20241002_SAAGAW0007_m3m_50mAGL_ortho_MS.cog.tif at /home/jamesg/test_data/naturescan/BonBon/SAAGAW0007/20241002_SAAGAW0007_m3m_50mAGL_ortho_MS.thumbnail.png
# Processing 20241002_SAASTP0033_m3m_100mAGL_ortho_MS.cog.tif (6 / 20) ...
# Successfully created thumbnail for 20241002_SAASTP0033_m3m_100mAGL_ortho_MS.cog.tif at /home/jamesg/test_data/naturescan/BonBon/SAASTP0033/20241002_SAASTP0033_m3m_100mAGL_ortho_MS.thumbnail.png
# Processing 20241001_SAAGAW0008_m3m_100mAGL_ortho_ms.cog.tif (7 / 20) ...
# Successfully created thumbnail for 20241001_SAAGAW0008_m3m_100mAGL_ortho_ms.cog.tif at /home/jamesg/test_data/naturescan/BonBon/SAAGAW0008/20241001_SAAGAW0008_m3m_100mAGL_ortho_ms.thumbnail.png
# Processing 20241001_SAAGAW0009_m3m_50mAGL_ortho_MS.cog.tif (8 / 20) ...
# Successfully created thumbnail for 20241001_SAAGAW0009_m3m_50mAGL_ortho_MS.cog.tif at /home/jamesg/test_data/naturescan/BonBon/SAAGAW0009/20241001_SAAGAW0009_m3m_50mAGL_ortho_MS.thumbnail.png
# Processing 20241001_SAAGAW0004_m3m_50mAGL_ortho_MS.cog.tif (9 / 20) ...
# Successfully created thumbnail for 20241001_SAAGAW0004_m3m_50mAGL_ortho_MS.cog.tif at /home/jamesg/test_data/naturescan/BonBon/SAAGAW0004/20241001/20241001_SAAGAW0004_m3m_50mAGL_ortho_MS.thumbnail.png
# Processing 20240925_NTAFIN0014_m3m_100mAGL_ortho_MS.cog.tif (10 / 20) ...
# Successfully created thumbnail for 20240925_NTAFIN0014_m3m_100mAGL_ortho_MS.cog.tif at /home/jamesg/test_data/naturescan/NTAFIN/NTAFIN0014/20240925_NTAFIN0014_m3m_100mAGL_ortho_MS.thumbnail.png
# Processing 20240925_NTAFIN0013_m3m_50mAGL_ortho_MS.cog.tif (11 / 20) ...
# Successfully created thumbnail for 20240925_NTAFIN0013_m3m_50mAGL_ortho_MS.cog.tif at /home/jamesg/test_data/naturescan/NTAFIN/NTAFIN0013/20240925_NTAFIN0013_m3m_50mAGL_ortho_MS.thumbnail.png
# Processing 20241210_SANSSTP014_m3m_50mAGL_ortho_ms.cog.tif (12 / 20) ...
# Successfully created thumbnail for 20241210_SANSSTP014_m3m_50mAGL_ortho_ms.cog.tif at /home/jamesg/test_data/naturescan/EvelynDowns/SANSSTP014/20241210_SANSSTP014_m3m_50mAGL_ortho_ms.thumbnail.png
# Processing 20241210_SANSSTP020_m3m_50mAGL_ortho_ms.cog.tif (13 / 20) ...
# Successfully created thumbnail for 20241210_SANSSTP020_m3m_50mAGL_ortho_ms.cog.tif at /home/jamesg/test_data/naturescan/EvelynDowns/SANSSTP020/20241210_SANSSTP020_m3m_50mAGL_ortho_ms.thumbnail.png
# Processing 20240812_SANSSTP009_m3m_70mAGL_ortho_ms.cog.tif (14 / 20) ...
# Successfully created thumbnail for 20240812_SANSSTP009_m3m_70mAGL_ortho_ms.cog.tif at /home/jamesg/test_data/naturescan/EvelynDowns/SANSSTP009/20240812_SANSSTP009_m3m_70mAGL_ortho_ms.thumbnail.png
# Processing 20241209_SANSSTP010_m3m_50mAGL_ortho_ms.cog.tif (15 / 20) ...
# Successfully created thumbnail for 20241209_SANSSTP010_m3m_50mAGL_ortho_ms.cog.tif at /home/jamesg/test_data/naturescan/EvelynDowns/SANSSTP010/20241209_SANSSTP010_m3m_50mAGL_ortho_ms.thumbnail.png
# Processing 20241208_SANSSTP005_m3m_60mAGL_ortho_ms.cog.tif (16 / 20) ...
# Successfully created thumbnail for 20241208_SANSSTP005_m3m_60mAGL_ortho_ms.cog.tif at /home/jamesg/test_data/naturescan/EvelynDowns/SANSSTP005/20241208_SANSSTP005_m3m_60mAGL_ortho_ms.thumbnail.png
# Processing 20241208_SANSSTP006_m3m_110mAGL_ortho_ms.cog.tif (17 / 20) ...
# Successfully created thumbnail for 20241208_SANSSTP006_m3m_110mAGL_ortho_ms.cog.tif at /home/jamesg/test_data/naturescan/EvelynDowns/SANSSTP006/20241208_SANSSTP006_m3m_110mAGL_ortho_ms.thumbnail.png
# Processing 20241210_SANSSTP016_m3m_50mAGL_ortho_MS.cog.tif (18 / 20) ...
# Successfully created thumbnail for 20241210_SANSSTP016_m3m_50mAGL_ortho_MS.cog.tif at /home/jamesg/test_data/naturescan/EvelynDowns/SANSSTP016/20241210_SANSSTP016_m3m_50mAGL_ortho_MS.thumbnail.png
# Processing 20241207_SANSSTP002_m3m_50mAGL_ortho_ms.cog.tif (19 / 20) ...
# Successfully created thumbnail for 20241207_SANSSTP002_m3m_50mAGL_ortho_ms.cog.tif at /home/jamesg/test_data/naturescan/EvelynDowns/SANSSTP002/20241207_SANSSTP002_m3m_50mAGL_ortho_ms.thumbnail.png
# Processing 20241208_SAASTP0041_m3m_50mAGL_ortho_MS.cog.tif (20 / 20) ...
# Successfully created thumbnail for 20241208_SAASTP0041_m3m_50mAGL_ortho_MS.cog.tif at /home/jamesg/test_data/naturescan/EvelynDowns/SANSSTP0041/20241208_SAASTP0041_m3m_50mAGL_ortho_MS.thumbnail.png
